# %%
#Import the dependencies.
import pandas as pd
import numpy as np
from config import weather_api_key
import random
import requests
from datetime import datetime
from citipy import citipy

# %%
# Generate a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Create a call out to openweathermap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longtitudes to a list
coordinates = list(lats_lngs)

# Create a list to hold the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confim sufficient count.
len(cities)
# Out:
# 734

# %%
# create an empty list to hold the weather daya.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | busselton
# Processing Record 2 of Set 15 | lagoa
# Processing Record 3 of Set 15 | port hardy
# Processing Record 4 of Set 15 | whitehorse
# Processing Record 5 of Set 15 | jamestown
# Processing Record 6 of Set 15 | zhigansk
# Processing Record 7 of Set 15 | hilo
# Processing Record 8 of Set 15 | thompson
# Processing Record 9 of Set 15 | vaini
# Processing Record 10 of Set 15 | rikitea
# Processing Record 11 of Set 15 | katsuura
# Processing Record 12 of Set 15 | ribeira grande
# Processing Record 13 of Set 15 | omboue
# Processing Record 14 of Set 15 | norman wells
# Processing Record 15 of Set 15 | albany
# Processing Record 16 of Set 15 | texarkana
# Processing Record 17 of Set 15 | carnarvon
# Processing Record 18 of Set 15 | new norfolk
# Processing Record 19 of Set 15 | punta arenas
# Processing Record 20 of Set 15 | meulaboh
# Processing Record 21 of Set 15 | novyy urengoy
# Processing Record 22 of Set 15 | bubaque
# Processing Record 23 of Set 15 | liverpool
# Processing Record 24 of Set 15 | mar del plata
# Processing Record 25 of Set 15 | lebu
# Processing Record 26 of Set 15 | hermanus
# Processing Record 27 of Set 15 | barrow
# Processing Record 28 of Set 15 | parabel
# Processing Record 29 of Set 15 | yulara
# Processing Record 30 of Set 15 | pontes e lacerda
# Processing Record 31 of Set 15 | pochutla
# Processing Record 32 of Set 15 | mataura
# Processing Record 33 of Set 15 | mabaruma
# Processing Record 34 of Set 15 | leshukonskoye
# Processing Record 35 of Set 15 | kashan
# Processing Record 36 of Set 15 | atuona
# Processing Record 37 of Set 15 | comodoro rivadavia
# Processing Record 38 of Set 15 | bahia honda
# Processing Record 39 of Set 15 | shimoda
# Processing Record 40 of Set 15 | tromso
# Processing Record 41 of Set 15 | agapovka
# Processing Record 42 of Set 15 | bani walid
# Processing Record 43 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 15 | kulhudhuffushi
# Processing Record 45 of Set 15 | mehamn
# Processing Record 46 of Set 15 | yellowknife
# Processing Record 47 of Set 15 | tuktoyaktuk
# Processing Record 48 of Set 15 | chuy
# Processing Record 49 of Set 15 | hambantota
# Processing Record 50 of Set 15 | bluff
# Processing Record 1 of Set 16 | alofi
# Processing Record 2 of Set 16 | jedrzejow
# Processing Record 3 of Set 16 | rio gallegos
# Processing Record 4 of Set 16 | portpatrick
# City not found. Skipping...
# Processing Record 5 of Set 16 | garbolovo
# Processing Record 6 of Set 16 | tiksi
# Processing Record 7 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 16 | upernavik
# Processing Record 9 of Set 16 | chokurdakh
# Processing Record 10 of Set 16 | vardo
# Processing Record 11 of Set 16 | saskylakh
# Processing Record 12 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 16 | necochea
# Processing Record 14 of Set 16 | dingle
# Processing Record 15 of Set 16 | lavrentiya
# Processing Record 16 of Set 16 | sydney
# Processing Record 17 of Set 16 | kondagaon
# Processing Record 18 of Set 16 | sirvintos
# Processing Record 19 of Set 16 | barra do garcas
# Processing Record 20 of Set 16 | ilulissat
# Processing Record 21 of Set 16 | praia da vitoria
# Processing Record 22 of Set 16 | mayskiy
# Processing Record 23 of Set 16 | qaanaaq
# Processing Record 24 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 16 | the valley
# Processing Record 26 of Set 16 | kavaratti
# Processing Record 27 of Set 16 | tilbury
# Processing Record 28 of Set 16 | ushuaia
# Processing Record 29 of Set 16 | avarua
# Processing Record 30 of Set 16 | kaitangata
# Processing Record 31 of Set 16 | nemuro
# Processing Record 32 of Set 16 | estelle
# Processing Record 33 of Set 16 | clyde river
# Processing Record 34 of Set 16 | yenagoa
# Processing Record 35 of Set 16 | cape town
# Processing Record 36 of Set 16 | bondoukou
# Processing Record 37 of Set 16 | narasannapeta
# Processing Record 38 of Set 16 | savannah bight
# Processing Record 39 of Set 16 | souillac
# Processing Record 40 of Set 16 | hobart
# Processing Record 41 of Set 16 | port elizabeth
# Processing Record 42 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 16 | margate
# Processing Record 44 of Set 16 | te anau
# Processing Record 45 of Set 16 | rawlins
# Processing Record 46 of Set 16 | castro
# Processing Record 47 of Set 16 | dawlatabad
# Processing Record 48 of Set 16 | jimma
# Processing Record 49 of Set 16 | bredasdorp
# Processing Record 50 of Set 16 | brae
# Processing Record 1 of Set 17 | severnyy
# Processing Record 2 of Set 17 | port alfred
# Processing Record 3 of Set 17 | kodiak
# Processing Record 4 of Set 17 | torbay
# Processing Record 5 of Set 17 | kapaa
# Processing Record 6 of Set 17 | warmbad
# Processing Record 7 of Set 17 | angoche
# Processing Record 8 of Set 17 | acurenam
# Processing Record 9 of Set 17 | tiarei
# Processing Record 10 of Set 17 | faya
# Processing Record 11 of Set 17 | mackenzie
# Processing Record 12 of Set 17 | bambous virieux
# Processing Record 13 of Set 17 | manggar
# Processing Record 14 of Set 17 | codrington
# Processing Record 15 of Set 17 | los llanos de aridane
# Processing Record 16 of Set 17 | vanino
# Processing Record 17 of Set 17 | hithadhoo
# Processing Record 18 of Set 17 | bulungu
# Processing Record 19 of Set 17 | sakaiminato
# Processing Record 20 of Set 17 | atbasar
# Processing Record 21 of Set 17 | tocopilla
# Processing Record 22 of Set 17 | matara
# Processing Record 23 of Set 17 | meybod
# Processing Record 24 of Set 17 | nizhniy kuranakh
# Processing Record 25 of Set 17 | atar
# Processing Record 26 of Set 17 | dunedin
# Processing Record 27 of Set 17 | shingu
# Processing Record 28 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 17 | kerema
# Processing Record 30 of Set 17 | kropotkin
# Processing Record 31 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 17 | xining
# Processing Record 33 of Set 17 | namibe
# Processing Record 34 of Set 17 | maputo
# Processing Record 35 of Set 17 | butaritari
# Processing Record 36 of Set 17 | luderitz
# Processing Record 37 of Set 17 | san patricio
# Processing Record 38 of Set 17 | bulaevo
# Processing Record 39 of Set 17 | sobolevo
# Processing Record 40 of Set 17 | samarai
# Processing Record 41 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 17 | amposta
# Processing Record 43 of Set 17 | colares
# Processing Record 44 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 17 | yuci
# Processing Record 46 of Set 17 | buraydah
# Processing Record 47 of Set 17 | leningradskiy
# Processing Record 48 of Set 17 | sayyan
# Processing Record 49 of Set 17 | bengkulu
# Processing Record 50 of Set 17 | mahebourg
# Processing Record 1 of Set 18 | viedma
# Processing Record 2 of Set 18 | pooler
# Processing Record 3 of Set 18 | gejiu
# Processing Record 4 of Set 18 | avanigadda
# Processing Record 5 of Set 18 | puerto ayora
# Processing Record 6 of Set 18 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 18 | porto santo
# Processing Record 8 of Set 18 | thunder bay
# Processing Record 9 of Set 18 | chifeng
# Processing Record 10 of Set 18 | mao
# Processing Record 11 of Set 18 | umm lajj
# Processing Record 12 of Set 18 | cabo san lucas
# Processing Record 13 of Set 18 | aykhal
# Processing Record 14 of Set 18 | aklavik
# Processing Record 15 of Set 18 | venezuela
# Processing Record 16 of Set 18 | yongan
# Processing Record 17 of Set 18 | roald
# Processing Record 18 of Set 18 | oranjemund
# Processing Record 19 of Set 18 | puerto ayacucho
# Processing Record 20 of Set 18 | lompoc
# Processing Record 21 of Set 18 | mezotur
# Processing Record 22 of Set 18 | kharp
# Processing Record 23 of Set 18 | mount gambier
# Processing Record 24 of Set 18 | ucluelet
# Processing Record 25 of Set 18 | lorengau
# Processing Record 26 of Set 18 | palaiokhora
# City not found. Skipping...
# Processing Record 27 of Set 18 | east london
# Processing Record 28 of Set 18 | san javier
# Processing Record 29 of Set 18 | aasiaat
# Processing Record 30 of Set 18 | ponta do sol
# Processing Record 31 of Set 18 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 18 | rafai
# Processing Record 33 of Set 18 | kahului
# Processing Record 34 of Set 18 | la ronge
# Processing Record 35 of Set 18 | anadyr
# Processing Record 36 of Set 18 | north platte
# Processing Record 37 of Set 18 | vestmannaeyjar
# Processing Record 38 of Set 18 | folldal
# Processing Record 39 of Set 18 | goderich
# Processing Record 40 of Set 18 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 18 | victoria
# Processing Record 42 of Set 18 | nikolskoye
# Processing Record 43 of Set 18 | les cayes
# Processing Record 44 of Set 18 | beringovskiy
# Processing Record 45 of Set 18 | ahmadpur
# Processing Record 46 of Set 18 | tautira
# Processing Record 47 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 18 | tilichiki
# Processing Record 49 of Set 18 | kaeo
# Processing Record 50 of Set 18 | geraldton
# Processing Record 1 of Set 19 | saint george
# Processing Record 2 of Set 19 | guerrero negro
# Processing Record 3 of Set 19 | monte carmelo
# Processing Record 4 of Set 19 | kruisfontein
# Processing Record 5 of Set 19 | road town
# Processing Record 6 of Set 19 | taoudenni
# Processing Record 7 of Set 19 | tolaga bay
# Processing Record 8 of Set 19 | fortuna
# Processing Record 9 of Set 19 | pamfila
# Processing Record 10 of Set 19 | richards bay
# Processing Record 11 of Set 19 | acapulco
# Processing Record 12 of Set 19 | krasnoselkup
# Processing Record 13 of Set 19 | taybad
# Processing Record 14 of Set 19 | dikson
# Processing Record 15 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 19 | cherskiy
# Processing Record 17 of Set 19 | boguchany
# Processing Record 18 of Set 19 | porto recanati
# Processing Record 19 of Set 19 | siniscola
# Processing Record 20 of Set 19 | tasiilaq
# Processing Record 21 of Set 19 | atherton
# Processing Record 22 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 19 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 19 | surt
# Processing Record 25 of Set 19 | mandalgovi
# Processing Record 26 of Set 19 | jilib
# Processing Record 27 of Set 19 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 19 | bud
# Processing Record 29 of Set 19 | laizhou
# Processing Record 30 of Set 19 | khatanga
# Processing Record 31 of Set 19 | okato
# Processing Record 32 of Set 19 | wagar
# Processing Record 33 of Set 19 | vila
# Processing Record 34 of Set 19 | gushikawa
# Processing Record 35 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 19 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 19 | hobyo
# Processing Record 38 of Set 19 | berlevag
# Processing Record 39 of Set 19 | sterling
# Processing Record 40 of Set 19 | lata
# Processing Record 41 of Set 19 | rolim de moura
# City not found. Skipping...
# Processing Record 42 of Set 19 | ixtapa
# Processing Record 43 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 19 | sao filipe
# Processing Record 45 of Set 19 | port-gentil
# Processing Record 46 of Set 19 | anloga
# Processing Record 47 of Set 19 | puerto narino
# Processing Record 48 of Set 19 | grenville
# Processing Record 49 of Set 19 | borazjan
# Processing Record 50 of Set 19 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 20 | waconia
# Processing Record 2 of Set 20 | faanui
# Processing Record 3 of Set 20 | farah
# Processing Record 4 of Set 20 | araouane
# Processing Record 5 of Set 20 | sorland
# Processing Record 6 of Set 20 | turayf
# Processing Record 7 of Set 20 | bandarbeyla
# Processing Record 8 of Set 20 | caravelas
# Processing Record 9 of Set 20 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 20 | oriximina
# Processing Record 11 of Set 20 | houston
# Processing Record 12 of Set 20 | kieta
# Processing Record 13 of Set 20 | san rafael del sur
# Processing Record 14 of Set 20 | yumen
# Processing Record 15 of Set 20 | pangody
# Processing Record 16 of Set 20 | zemio
# Processing Record 17 of Set 20 | pisco
# Processing Record 18 of Set 20 | tawnat
# City not found. Skipping...
# Processing Record 19 of Set 20 | xai-xai
# Processing Record 20 of Set 20 | uglich
# Processing Record 21 of Set 20 | srednekolymsk
# Processing Record 22 of Set 20 | airai
# Processing Record 23 of Set 20 | atambua
# Processing Record 24 of Set 20 | sitka
# Processing Record 25 of Set 20 | puerto escondido
# Processing Record 26 of Set 20 | belem de sao francisco
# Processing Record 27 of Set 20 | kapit
# Processing Record 28 of Set 20 | dom pedrito
# Processing Record 29 of Set 20 | nhulunbuy
# Processing Record 30 of Set 20 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 20 | muros
# Processing Record 32 of Set 20 | west bay
# Processing Record 33 of Set 20 | georgetown
# Processing Record 34 of Set 20 | ostrovnoy
# Processing Record 35 of Set 20 | iqaluit
# Processing Record 36 of Set 20 | sabang
# Processing Record 37 of Set 20 | aktas
# Processing Record 38 of Set 20 | eyrarbakki
# Processing Record 39 of Set 20 | sabha
# Processing Record 40 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 20 | ailigandi
# Processing Record 42 of Set 20 | pangnirtung
# Processing Record 43 of Set 20 | havre-saint-pierre
# Processing Record 44 of Set 20 | conceicao do araguaia
# Processing Record 45 of Set 20 | longyearbyen
# Processing Record 46 of Set 20 | dombarovskiy
# Processing Record 47 of Set 20 | enterprise
# Processing Record 48 of Set 20 | pacific grove
# Processing Record 49 of Set 20 | cidreira
# Processing Record 50 of Set 20 | presidencia roque saenz pena
# Processing Record 1 of Set 21 | koumra
# Processing Record 2 of Set 21 | saint-augustin
# Processing Record 3 of Set 21 | kerteh
# City not found. Skipping...
# Processing Record 4 of Set 21 | pueblo
# Processing Record 5 of Set 21 | naze
# Processing Record 6 of Set 21 | marzuq
# Processing Record 7 of Set 21 | saint-philippe
# Processing Record 8 of Set 21 | ahipara
# Processing Record 9 of Set 21 | ilebo
# Processing Record 10 of Set 21 | santa fe
# Processing Record 11 of Set 21 | luau
# Processing Record 12 of Set 21 | joshimath
# Processing Record 13 of Set 21 | bilibino
# Processing Record 14 of Set 21 | panama city
# Processing Record 15 of Set 21 | hofn
# Processing Record 16 of Set 21 | nizhnevartovsk
# Processing Record 17 of Set 21 | karratha
# Processing Record 18 of Set 21 | cayenne
# Processing Record 19 of Set 21 | luwuk
# Processing Record 20 of Set 21 | mikhaylovka
# Processing Record 21 of Set 21 | gwanda
# Processing Record 22 of Set 21 | provideniya
# Processing Record 23 of Set 21 | chake chake
# Processing Record 24 of Set 21 | basco
# Processing Record 25 of Set 21 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 21 | hue
# Processing Record 27 of Set 21 | katobu
# Processing Record 28 of Set 21 | lasa
# Processing Record 29 of Set 21 | harper
# Processing Record 30 of Set 21 | wanaka
# Processing Record 31 of Set 21 | oktyabrskiy
# Processing Record 32 of Set 21 | nijar
# Processing Record 33 of Set 21 | broken hill
# Processing Record 34 of Set 21 | arraial do cabo
# Processing Record 35 of Set 21 | chacabuco
# Processing Record 36 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 21 | armacao dos buzios
# City not found. Skipping...
# Processing Record 38 of Set 21 | vao
# Processing Record 39 of Set 21 | buchanan
# Processing Record 40 of Set 21 | san jose
# Processing Record 41 of Set 21 | evensk
# Processing Record 42 of Set 21 | biak
# Processing Record 43 of Set 21 | miandrivazo
# Processing Record 44 of Set 21 | kerman
# Processing Record 45 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 21 | tuatapere
# Processing Record 47 of Set 21 | komsomolskiy
# Processing Record 48 of Set 21 | suoyarvi
# Processing Record 49 of Set 21 | vila velha
# Processing Record 50 of Set 21 | arcachon
# Processing Record 1 of Set 22 | port charlotte
# Processing Record 2 of Set 22 | charlottesville
# Processing Record 3 of Set 22 | coahuayana
# Processing Record 4 of Set 22 | avera
# Processing Record 5 of Set 22 | banmo
# City not found. Skipping...
# Processing Record 6 of Set 22 | hirara
# Processing Record 7 of Set 22 | pouebo
# Processing Record 8 of Set 22 | san policarpo
# Processing Record 9 of Set 22 | khandyga
# Processing Record 10 of Set 22 | doha
# Processing Record 11 of Set 22 | shenjiamen
# Processing Record 12 of Set 22 | semirom
# Processing Record 13 of Set 22 | pultusk
# Processing Record 14 of Set 22 | tessalit
# Processing Record 15 of Set 22 | kenora
# Processing Record 16 of Set 22 | korla
# Processing Record 17 of Set 22 | beboto
# Processing Record 18 of Set 22 | dogondoutchi
# Processing Record 19 of Set 22 | fare
# Processing Record 20 of Set 22 | talnakh
# Processing Record 21 of Set 22 | san cristobal
# Processing Record 22 of Set 22 | maceio
# Processing Record 23 of Set 22 | borgarnes
# Processing Record 24 of Set 22 | caranavi
# Processing Record 25 of Set 22 | sao marcos
# Processing Record 26 of Set 22 | pevek
# Processing Record 27 of Set 22 | ponta delgada
# Processing Record 28 of Set 22 | medea
# Processing Record 29 of Set 22 | vostok
# Processing Record 30 of Set 22 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 22 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 22 | mantua
# Processing Record 33 of Set 22 | ajra
# Processing Record 34 of Set 22 | redmond
# Processing Record 35 of Set 22 | coihaique
# Processing Record 36 of Set 22 | saint anthony
# Processing Record 37 of Set 22 | dedza
# Processing Record 38 of Set 22 | charters towers
# Processing Record 39 of Set 22 | egvekinot
# Processing Record 40 of Set 22 | ust-omchug
# Processing Record 41 of Set 22 | listvyanskiy
# Processing Record 42 of Set 22 | kasongo
# Processing Record 43 of Set 22 | yar-sale
# Processing Record 44 of Set 22 | saint marys
# Processing Record 45 of Set 22 | marawi
# Processing Record 46 of Set 22 | gravesend
# Processing Record 47 of Set 22 | markova
# Processing Record 48 of Set 22 | zlynka
# Processing Record 49 of Set 22 | birsk
# Processing Record 50 of Set 22 | launceston
# Processing Record 1 of Set 23 | callaway
# Processing Record 2 of Set 23 | saint-pierre
# Processing Record 3 of Set 23 | camopi
# Processing Record 4 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 23 | santiago del estero
# Processing Record 6 of Set 23 | carutapera
# Processing Record 7 of Set 23 | ust-kuyga
# Processing Record 8 of Set 23 | joao pinheiro
# Processing Record 9 of Set 23 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 23 | balkhash
# Processing Record 11 of Set 23 | grand-lahou
# Processing Record 12 of Set 23 | salinopolis
# Processing Record 13 of Set 23 | ouesso
# Processing Record 14 of Set 23 | san pedro jocopilas
# Processing Record 15 of Set 23 | wattegama
# Processing Record 16 of Set 23 | santa maria
# Processing Record 17 of Set 23 | bowen
# Processing Record 18 of Set 23 | chapais
# Processing Record 19 of Set 23 | nanortalik
# Processing Record 20 of Set 23 | liyang
# Processing Record 21 of Set 23 | xixiang
# Processing Record 22 of Set 23 | yerbogachen
# Processing Record 23 of Set 23 | katherine
# Processing Record 24 of Set 23 | gobo
# Processing Record 25 of Set 23 | la primavera
# Processing Record 26 of Set 23 | sur
# Processing Record 27 of Set 23 | ayagoz
# Processing Record 28 of Set 23 | meadow lake
# Processing Record 29 of Set 23 | fukuma
# Processing Record 30 of Set 23 | barcelos
# Processing Record 31 of Set 23 | mandera
# Processing Record 32 of Set 23 | manjacaze
# Processing Record 33 of Set 23 | tera
# Processing Record 34 of Set 23 | pamekasan
# Processing Record 35 of Set 23 | kavieng
# Processing Record 36 of Set 23 | severo-kurilsk
# Processing Record 37 of Set 23 | umm bab
# Processing Record 38 of Set 23 | rocha
# Processing Record 39 of Set 23 | eustis
# Processing Record 40 of Set 23 | boa vista
# Processing Record 41 of Set 23 | irtyshskiy
# Processing Record 42 of Set 23 | fuling
# Processing Record 43 of Set 23 | lokosovo
# Processing Record 44 of Set 23 | jujuy
# City not found. Skipping...
# Processing Record 45 of Set 23 | stornoway
# Processing Record 46 of Set 23 | blue springs
# Processing Record 47 of Set 23 | iquitos
# Processing Record 48 of Set 23 | tazmalt
# Processing Record 49 of Set 23 | bend
# Processing Record 50 of Set 23 | tigil
# Processing Record 1 of Set 24 | kroya
# Processing Record 2 of Set 24 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 24 | pattaya
# Processing Record 4 of Set 24 | padang
# Processing Record 5 of Set 24 | tome-acu
# City not found. Skipping...
# Processing Record 6 of Set 24 | port lincoln
# Processing Record 7 of Set 24 | san felipe
# Processing Record 8 of Set 24 | prince rupert
# Processing Record 9 of Set 24 | gorin
# Processing Record 10 of Set 24 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 24 | matadi
# Processing Record 12 of Set 24 | grand gaube
# Processing Record 13 of Set 24 | sola
# Processing Record 14 of Set 24 | polovinnoye
# Processing Record 15 of Set 24 | angouleme
# Processing Record 16 of Set 24 | vila franca do campo
# Processing Record 17 of Set 24 | laibin
# Processing Record 18 of Set 24 | orikum
# Processing Record 19 of Set 24 | coquimbo
# Processing Record 20 of Set 24 | martinsicuro
# Processing Record 21 of Set 24 | kattivakkam
# Processing Record 22 of Set 24 | kuusalu
# Processing Record 23 of Set 24 | north bend
# Processing Record 24 of Set 24 | ahumada
# City not found. Skipping...
# Processing Record 25 of Set 24 | isangel
# Processing Record 26 of Set 24 | sao joao da barra
# Processing Record 27 of Set 24 | labuhan
# Processing Record 28 of Set 24 | linhai
# Processing Record 29 of Set 24 | bethel
# Processing Record 30 of Set 24 | itarema
# Processing Record 31 of Set 24 | ancud
# Processing Record 32 of Set 24 | saldanha
# Processing Record 33 of Set 24 | takoradi
# Processing Record 34 of Set 24 | bereda
# Processing Record 35 of Set 24 | penarroya-pueblonuevo
# Processing Record 36 of Set 24 | kutum
# Processing Record 37 of Set 24 | tiruvottiyur
# City not found. Skipping...
# Processing Record 38 of Set 24 | puerto palomas
# Processing Record 39 of Set 24 | miyang
# Processing Record 40 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 24 | guaimaro
# Processing Record 42 of Set 24 | imphal
# Processing Record 43 of Set 24 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 24 | kota belud
# Processing Record 45 of Set 24 | nerchinskiy zavod
# Processing Record 46 of Set 24 | chihuahua
# Processing Record 47 of Set 24 | panjab
# Processing Record 48 of Set 24 | zlotow
# Processing Record 49 of Set 24 | peabiru
# Processing Record 50 of Set 24 | durusu
# Processing Record 1 of Set 25 | antofagasta
# Processing Record 2 of Set 25 | mujiayingzi
# Processing Record 3 of Set 25 | duluth
# Processing Record 4 of Set 25 | nakasongola
# Processing Record 5 of Set 25 | nizhniy odes
# Processing Record 6 of Set 25 | tura
# Processing Record 7 of Set 25 | muravlenko
# Processing Record 8 of Set 25 | winton
# Processing Record 9 of Set 25 | bijar
# Processing Record 10 of Set 25 | bani
# Processing Record 11 of Set 25 | ironton
# Processing Record 12 of Set 25 | sarishabari
# Processing Record 13 of Set 25 | tateyama
# Processing Record 14 of Set 25 | flin flon
# Processing Record 15 of Set 25 | shenkursk
# Processing Record 16 of Set 25 | praya
# Processing Record 17 of Set 25 | tadine
# Processing Record 18 of Set 25 | kloulklubed
# Processing Record 19 of Set 25 | kununurra
# Processing Record 20 of Set 25 | iroquois falls
# Processing Record 21 of Set 25 | virbalis
# Processing Record 22 of Set 25 | lakes entrance
# Processing Record 23 of Set 25 | toda raisingh
# Processing Record 24 of Set 25 | pahalgam
# Processing Record 25 of Set 25 | unye
# City not found. Skipping...
# Processing Record 26 of Set 25 | nantucket
# Processing Record 27 of Set 25 | nelson bay
# Processing Record 28 of Set 25 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 25 | gweru
# Processing Record 30 of Set 25 | hasaki
# Processing Record 31 of Set 25 | zwedru
# Processing Record 32 of Set 25 | portland
# Processing Record 33 of Set 25 | bosaso
# Processing Record 34 of Set 25 | thayetmyo
# Processing Record 35 of Set 25 | pedasi
# Processing Record 36 of Set 25 | inhumas
# Processing Record 37 of Set 25 | wawa
# Processing Record 38 of Set 25 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 25 | palmer
# Processing Record 40 of Set 25 | flinders
# Processing Record 41 of Set 25 | pjanici
# Processing Record 42 of Set 25 | raudeberg
# Processing Record 43 of Set 25 | jalu
# Processing Record 44 of Set 25 | rimouski
# Processing Record 45 of Set 25 | kachikau
# City not found. Skipping...
# Processing Record 46 of Set 25 | dangriga
# Processing Record 47 of Set 25 | ajaccio
# Processing Record 48 of Set 25 | salalah
# Processing Record 49 of Set 25 | pathein
# Processing Record 50 of Set 25 | linqiong
# Processing Record 1 of Set 26 | san rafael
# Processing Record 2 of Set 26 | paamiut
# Processing Record 3 of Set 26 | kupang
# Processing Record 4 of Set 26 | salym
# Processing Record 5 of Set 26 | bilma
# Processing Record 6 of Set 26 | durant
# Processing Record 7 of Set 26 | darhan
# Processing Record 8 of Set 26 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 26 | sturgis
# Processing Record 10 of Set 26 | chicama
# Processing Record 11 of Set 26 | bonavista
# Processing Record 12 of Set 26 | santa ana
# Processing Record 13 of Set 26 | boende
# Processing Record 14 of Set 26 | beyneu
# Processing Record 15 of Set 26 | axim
# Processing Record 16 of Set 26 | esperance
# Processing Record 17 of Set 26 | semnan
# Processing Record 18 of Set 26 | seoul
# Processing Record 19 of Set 26 | aden
# Processing Record 20 of Set 26 | sug-aksy
# City not found. Skipping...
# Processing Record 21 of Set 26 | jerome
# Processing Record 22 of Set 26 | bafra
# Processing Record 23 of Set 26 | quatre cocos
# Processing Record 24 of Set 26 | smirnykh
# Processing Record 25 of Set 26 | nakusp
# Processing Record 26 of Set 26 | aripuana
# Processing Record 27 of Set 26 | natal
# Processing Record 28 of Set 26 | pasco
# Processing Record 29 of Set 26 | college
# Processing Record 30 of Set 26 | bukachacha
# Processing Record 31 of Set 26 | carlisle
# Processing Record 32 of Set 26 | male
# Processing Record 33 of Set 26 | morgan city
# Processing Record 34 of Set 26 | jacksonville
# Processing Record 35 of Set 26 | teguise
# Processing Record 36 of Set 26 | veraval
# Processing Record 37 of Set 26 | netishyn
# Processing Record 38 of Set 26 | hesla
# Processing Record 39 of Set 26 | indi
# Processing Record 40 of Set 26 | dudinka
# Processing Record 41 of Set 26 | narsaq
# Processing Record 42 of Set 26 | neiafu
# Processing Record 43 of Set 26 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 26 | vostochnyy
# Processing Record 45 of Set 26 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 26 | la grande
# Processing Record 47 of Set 26 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 26 | inuvik
# Processing Record 49 of Set 26 | soverato
# Processing Record 50 of Set 26 | hegang
# Processing Record 1 of Set 27 | bundaberg
# Processing Record 2 of Set 27 | taylorville
# Processing Record 3 of Set 27 | porto novo
# Processing Record 4 of Set 27 | rock sound
# Processing Record 5 of Set 27 | alcudia
# Processing Record 6 of Set 27 | bumba
# Processing Record 7 of Set 27 | ardistan
# City not found. Skipping...
# Processing Record 8 of Set 27 | galle
# Processing Record 9 of Set 27 | puerto colombia
# Processing Record 10 of Set 27 | unecha
# Processing Record 11 of Set 27 | palmeirais
# Processing Record 12 of Set 27 | juquia
# Processing Record 13 of Set 27 | victor harbor
# Processing Record 14 of Set 27 | aksarka
# Processing Record 15 of Set 27 | kui buri
# Processing Record 16 of Set 27 | kitangari
# Processing Record 17 of Set 27 | sabzevar
# Processing Record 18 of Set 27 | xiuyan
# Processing Record 19 of Set 27 | husavik
# Processing Record 20 of Set 27 | pilao arcado
# City not found. Skipping...
# Processing Record 21 of Set 27 | mackay
# Processing Record 22 of Set 27 | kachiry
# Processing Record 23 of Set 27 | teguldet
# Processing Record 24 of Set 27 | nome
# Processing Record 25 of Set 27 | arman
# Processing Record 26 of Set 27 | mattawa
# Processing Record 27 of Set 27 | ambositra
# Processing Record 28 of Set 27 | qaqortoq
# Processing Record 29 of Set 27 | grindavik
# Processing Record 30 of Set 27 | hamilton
# Processing Record 31 of Set 27 | hirado
# Processing Record 32 of Set 27 | tucurui
# Processing Record 33 of Set 27 | awjilah
# Processing Record 34 of Set 27 | valladolid
# Processing Record 35 of Set 27 | sidi qasim
# City not found. Skipping...
# Processing Record 36 of Set 27 | filadelfia
# Processing Record 37 of Set 27 | yeniseysk
# Processing Record 38 of Set 27 | linxia
# Processing Record 39 of Set 27 | san pedro
# Processing Record 40 of Set 27 | half moon bay
# Processing Record 41 of Set 27 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 27 | rapid valley
# Processing Record 43 of Set 27 | wahiawa
# Processing Record 44 of Set 27 | poronaysk
# Processing Record 45 of Set 27 | constitucion
# Processing Record 46 of Set 27 | khorinsk
# Processing Record 47 of Set 27 | laguna
# Processing Record 48 of Set 27 | svetlaya
# Processing Record 49 of Set 27 | usogorsk
# Processing Record 50 of Set 27 | poya
# Processing Record 1 of Set 28 | asau
# Processing Record 2 of Set 28 | yeppoon
# Processing Record 3 of Set 28 | uruzgan
# Processing Record 4 of Set 28 | coalcoman
# City not found. Skipping...
# Processing Record 5 of Set 28 | spassk
# Processing Record 6 of Set 28 | belaya gora
# Processing Record 7 of Set 28 | karacabey
# Processing Record 8 of Set 28 | dumai
# Processing Record 9 of Set 28 | novi pazar
# Processing Record 10 of Set 28 | paita
# Processing Record 11 of Set 28 | kisangani
# Processing Record 12 of Set 28 | fort nelson
# Processing Record 13 of Set 28 | powell
# Processing Record 14 of Set 28 | aybak
# City not found. Skipping...
# Processing Record 15 of Set 28 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 28 | tignere
# Processing Record 17 of Set 28 | mundo nuevo
# Processing Record 18 of Set 28 | hami
# Processing Record 19 of Set 28 | sembakung
# Processing Record 20 of Set 28 | calvinia
# Processing Record 21 of Set 28 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 28 | ishigaki
# Processing Record 23 of Set 28 | milkovo
# Processing Record 24 of Set 28 | tornio
# Processing Record 25 of Set 28 | karsun
# Processing Record 26 of Set 28 | auki
# Processing Record 27 of Set 28 | pangkalanbuun
# Processing Record 28 of Set 28 | karlstad
# Processing Record 29 of Set 28 | sana
# Processing Record 30 of Set 28 | vanimo
# Processing Record 31 of Set 28 | yagodnoye
# Processing Record 32 of Set 28 | ranong
# Processing Record 33 of Set 28 | jadu
# Processing Record 34 of Set 28 | itaituba
# Processing Record 35 of Set 28 | thinadhoo
# Processing Record 36 of Set 28 | pitimbu
# Processing Record 37 of Set 28 | cam ranh
# Processing Record 38 of Set 28 | laje
# Processing Record 39 of Set 28 | andenes
# Processing Record 40 of Set 28 | henties bay
# Processing Record 41 of Set 28 | ahuimanu
# Processing Record 42 of Set 28 | alice springs
# Processing Record 43 of Set 28 | nishihara
# Processing Record 44 of Set 28 | liwale
# Processing Record 45 of Set 28 | nador
# Processing Record 46 of Set 28 | batagay-alyta
# Processing Record 47 of Set 28 | susanville
# Processing Record 48 of Set 28 | mingoyo
# Processing Record 49 of Set 28 | pali
# Processing Record 50 of Set 28 | sergeyevka
# Processing Record 1 of Set 29 | ylivieska
# Processing Record 2 of Set 29 | elko
# Processing Record 3 of Set 29 | zhigalovo
# Processing Record 4 of Set 29 | bathsheba
# Processing Record 5 of Set 29 | buala
# Processing Record 6 of Set 29 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 29 | kysyl-syr
# Processing Record 8 of Set 29 | rio cuarto
# Processing Record 9 of Set 29 | mbour
# Processing Record 10 of Set 29 | robinson
# Processing Record 11 of Set 29 | kamloops
# Processing Record 12 of Set 29 | christchurch
# Processing Record 13 of Set 29 | rakiv lis
# Processing Record 14 of Set 29 | khor
# Processing Record 15 of Set 29 | broome
# Processing Record 16 of Set 29 | dubti
# Processing Record 17 of Set 29 | la mesa
# Processing Record 18 of Set 29 | le port
# Processing Record 19 of Set 29 | akureyri
# Processing Record 20 of Set 29 | cururupu
# Processing Record 21 of Set 29 | naigarhi
# Processing Record 22 of Set 29 | nam tha
# City not found. Skipping...
# Processing Record 23 of Set 29 | golden
# Processing Record 24 of Set 29 | vallenar
# Processing Record 25 of Set 29 | walla walla
# Processing Record 26 of Set 29 | mahanoro
# Processing Record 27 of Set 29 | hebi
# Processing Record 28 of Set 29 | daloa
# Processing Record 29 of Set 29 | poum
# Processing Record 30 of Set 29 | fairbanks
# Processing Record 31 of Set 29 | pravia
# Processing Record 32 of Set 29 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 29 | teneguiban
# City not found. Skipping...
# Processing Record 34 of Set 29 | yvetot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 668

# %%
# Convert the array of dictionaries to a DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Busselton      AU -33.6500  115.3333     55.78        89           0
# 1       Lagoa      PT  39.0500  -27.9833     59.50        69          51
# 2  Port Hardy      CA  50.6996 -127.4199     46.58        71          75
# 3  Whitehorse      CA  60.7161 -135.0538     26.10        49          75
# 4   Jamestown      US  42.0970  -79.2353     35.24        74         100
#
#    Wind Speed Current Description
# 0        9.82           clear sky
# 1       12.35       broken clouds
# 2        9.22       broken clouds
# 3        0.00       broken clouds
# 4       23.02                snow

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
